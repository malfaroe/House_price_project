# %%
##Import libraries 

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
from datetime import datetime, timedelta

# import all libraries and dependencies for data visualization
pd.options.display.float_format='{:.4f}'.format
plt.rcParams['figure.figsize'] = [8,8]
pd.set_option('display.max_columns', 350)
pd.set_option('display.max_colwidth', -1) 
pd.set_option("display.max_rows", 300)
sns.set(style='darkgrid')
import matplotlib.ticker as ticker
import matplotlib.ticker as plticker


# import all libraries and dependencies for machine learning
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.base import TransformerMixin
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import RobustScaler

from sklearn.compose import make_column_transformer


import statsmodels.api as sm
from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import PolynomialFeatures

from scipy import stats
from scipy.stats import norm, kurtosis, skew

# Import specific libraries
import statsmodels.api as sm
from statsmodels.stats import diagnostic as diag
from statsmodels.stats.outliers_influence import variance_inflation_factor

pd.set_option('expand_frame_repr', False)

# %%
##FILTRAR: mas_cols  = all_data.filter(like='Mas', axis=1).columns

# %%
#Loading updated dataset

# %store -r all_data
# %store -r y_train
# %store -r data_b
# %store -r data_pool

# %%
###CORRELATION ANALYSIS WITH TARGET

# %%
data = all_data.iloc[:len(y_train), :]
data["SalePrice"] = y_train
corr = data.corr()
# best_corr = corr[abs(corr()["SalePrice"]) > 0.26]

# %%
corr.isnull().sum().sum()
# Out:
# 0

# %%
# import lr_module_mae 
# from lr_module_mae  import Linear_Regression
# #Generamos X e y
# y = np.log1p(data["SalePrice"]) #se transformó el target


# #Rescaling X
# scale = RobustScaler()
# X = scale.fit_transform(data[["ConstructArea"]])

# dataset_mae = pd.DataFrame(X, columns = ["ConstructArea"])
# dataset_mae["SalePrice"] = y.to_frame()

# %%
best_corr = corr[abs(corr["SalePrice"]) > 0.26]["SalePrice"]

# %%
best_corr.sort_values(ascending = False)[:11] ##lista de los 10 mejor correlacionados con precio
# Out:
# SalePrice           1.0000
# ConstructArea       0.8597
# TotalPoints         0.8460
# OverallQual         0.7934
# BsmtSFMultPoints    0.7762
# GrLivArea           0.7344
# GarageArea_x_Car    0.7074
# ExterQual           0.6839
# TotalExtraPoints    0.6786
# TotalBsmtSF_x_Bsm   0.6756
# KitchenQual         0.6614
# Name: SalePrice, dtype: float64

# %%
reg_col = best_corr.sort_values(ascending = False)[:11].index
reg_col
# Out:
# Index(['SalePrice', 'ConstructArea', 'TotalPoints', 'OverallQual',
#        'BsmtSFMultPoints', 'GrLivArea', 'GarageArea_x_Car', 'ExterQual',
#        'TotalExtraPoints', 'TotalBsmtSF_x_Bsm', 'KitchenQual'],
#       dtype='object')

# %%
filter = data.corr()[reg_col]
filter.loc[filter.index == "GrLivArea", :].max().max()
# Out:
# 1.0

# %%
filter
# Out:
#                        ConstructArea  TotalPoints  OverallQual  BsmtSFMultPoints  GrLivArea  GarageArea_x_Car  ExterQual  TotalExtraPoints  TotalBsmtSF_x_Bsm  KitchenQual
# LotFrontage           0.4090         0.2289       0.2049       0.2913            0.3416     0.3513            0.1496     0.2341            0.3275             0.1697
# LotArea               0.3857         0.1619       0.1335       0.2588            0.3447     0.2738            0.0832     0.1974            0.3156             0.1156
# Street                0.0539         0.0609       0.0622       0.0382            0.0624     0.0168            0.0709     0.0635            0.0319             0.0628
# SaleCondition_Partial 0.2485         0.3291       0.3276       0.3109            0.1617     0.3017            0.3799     0.2781            0.2368             0.3388
# Remod                 -0.0496        -0.0745      -0.0884      -0.1128           0.0634     -0.1064           -0.0627    0.0425            -0.0617            -0.0112
# New                   0.0496         0.0745       0.0884       0.1128            -0.0634    0.1064            0.0627     -0.0425           0.0617             0.0112
# Age                   -0.3952        -0.5960      -0.5721      -0.4473           -0.3194    -0.4099           -0.6074    -0.5137           -0.2687            -0.6140

# %%
viejo = ['FireplaceQu', 'BsmtSFPoints', 'TotalBsmtSF', 'GarageArea', 'GarageCars', 'OverallQual', 'GrLivArea', 
               'TotalBsmtSF_x_Bsm', '1stFlrSF', 'PoolArea', 'LotArea', 'SaleCondition_Partial', 'Exterior1st_VinylSd',
               'GarageCond', 'HouseStyle_2Story', 'BsmtSFMultPoints', 'ScreenPorch', 'LowQualFinSF', 'BsmtFinSF2',
               'TSsnPorch']

# %%
filter.loc[filter.index == "GarageArea_x_Car", :].max().max()
# Out:
# 1.0

# %%
#3Extraer los indexes que tienen mayores valores de correlacion con los best
highest = []
f_col = list(set(filter.index) - set(reg_col))
for c in f_col:
    if (filter.loc[filter.index == c, :].max().max() > 0.7):
        highest.append(c)
highest, len(highest)
# Out:
# (['BsmtSFPoints',
#   'BsmtQual',
#   'Fireplaces',
#   'TotalBsmtSF',
#   'GarageCars',
#   'TotRmsAbvGrd',
#   'GarageArea',
#   'FireplaceQu',
#   '1stFlrSF'],
#  9)

# %%
f_col
# Out:
# ['MoSold_10',
#  'SaleType_WD',
#  'TotalPorch',
#  'Exterior1st_Plywood',
#  'Condition1_Norm',
#  'Electrical_SBrkr',
#  'Neighborhood_BrDale',
#  'Neighborhood_ClearCr',
#  'Exterior2nd_Plywood',
#  'HouseStyle_2Story',
#  'GarageType_BuiltIn',
#  'MoSold_9',
#  'MoSold_3',
#  'Alley_Grvl',
#  'RoofStyle_Gambrel',
#  'MoSold_8',
#  'Neighborhood_Gilbert',
#  'MSSubClass_75',
#  'Age',
#  'Exterior1st_HdBoard',
#  'Exterior1st_VinylSd',
#  'HalfBath',
#  'LotFrontage',
#  'Heating_Wall',
#  'Exterior1st_CemntBd',
#  'HeatingQC',
#  'Exterior1st_MetalSd',
#  'Fence',
#  'BldgType_2fmCon',
#  'HouseStyle_1Story',
#  'LandContour_Lvl',
#  'Electrical_FuseF',
#  'BsmtHalfBath',
#  'BsmtSFPoints',
#  'YrSold',
#  'PoolQC',
#  'HouseStyle_1.5Fin',
#  'MoSold_4',
#  'Condition1_RRAe',
#  'MSSubClass_90',
#  'Alley_Pave',
#  'SaleCondition_Partial',
#  'Condition2_PosA',
#  'Neighborhood_Timber',
#  'MSSubClass_180',
#  'MoSold_5',
#  'BsmtQual',
#  'GarageType_CarPort',
#  'EnclosedPorch',
#  'Neighborhood_SawyerW',
#  'RoofStyle_Mansard',
#  'Condition1_RRAn',
#  'HouseStyle_SLvl',
#  'SaleType_Con',
#  'Exterior1st_Stucco',
#  'MSSubClass_120',
#  'LotArea',
#  'Street',
#  'LotConfig_FR3',
#  'MSSubClass_40',
#  'MSSubClass_20',
#  'Neighborhood_Somerst',
#  'RoofStyle_Gable',
#  'Exterior1st_BrkComm',
#  'LotConfig_CulDSac',
#  'Exterior2nd_Wd Sdng',
#  'Exterior2nd_Wd Shng',
#  'TotBathrooms',
#  'MoSold_11',
#  'BsmtFinSF1',
#  'GarageNewest',
#  'SaleCondition_Family',
#  'Heating_Grav',
#  'LandContour_Low',
#  'MiscFeature_Othr',
#  'Exterior2nd_Stone',
#  'OverallCond',
#  'RoofMatl_Tar&Grv',
#  'Condition1_PosA',
#  'BldgType_1Fam',
#  'HouseStyle_2.5Unf',
#  'RoofMatl_CompShg',
#  '3SsnPorch',
#  'MoSold_6',
#  'RoofMatl_WdShngl',
#  'MSSubClass_85',
#  'BsmtFinType2',
#  'MSSubClass_50',
#  'LotConfig_FR2',
#  'BldgType_Twnhs',
#  'New',
#  'YearRemodAdd',
#  'LowQualFinSF',
#  'SaleType_COD',
#  'BsmtCond',
#  'MSZoning_C (all)',
#  'Neighborhood_NAmes',
#  'Neighborhood_NPkVill',
#  'ExterCond',
#  'Neighborhood_Blmngtn',
#  'SaleCondition_Abnorml',
#  'Neighborhood_Blueste',
#  'BsmtFinSF2',
#  'Neighborhood_Veenker',
#  'MiscFeature_Pool',
#  'MoSold_12',
#  'MSSubClass_80',
#  'Exterior2nd_Stucco',
#  '2ndFlrSF',
#  'MSSubClass_60',
#  'Exterior1st_AsbShng',
#  'MiscFeature_Shed',
#  'HouseStyle_SFoyer',
#  'Exterior1st_Wd Sdng',
#  'GarageType_2Types',
#  'Condition2_Feedr',
#  'MSSubClass_70',
#  'MSZoning_RH',
#  'Exterior2nd_AsphShn',
#  'SaleType_ConLD',
#  'Fireplaces',
#  'GarageFinish',
#  'Exterior2nd_BrkFace',
#  'BldgType_TwnhsE',
#  'Exterior1st_AsphShn',
#  'Foundation_BrkTil',
#  'Exterior2nd_AsbShng',
#  'LandContour_Bnk',
#  'TotalBsmtSF',
#  'GarageType_NA',
#  'BsmtUnfSF',
#  'Exterior2nd_VinylSd',
#  'Heating_GasA',
#  'MSSubClass_30',
#  'MoSold_7',
#  'MiscFeature_Gar2',
#  'SaleType_ConLw',
#  'Remod',
#  'MSSubClass_190',
#  'Exterior2nd_MetalSd',
#  'LandSlope',
#  'YearBuilt',
#  'Exterior1st_BrkFace',
#  'GarageType_Detchd',
#  'Functional',
#  'Exterior2nd_Brk Cmn',
#  'Condition2_Norm',
#  'Foundation_Wood',
#  'ScreenPorch',
#  'Neighborhood_StoneBr',
#  'Condition2_PosN',
#  'Neighborhood_Sawyer',
#  'Neighborhood_NWAmes',
#  'Condition2_Artery',
#  'MasVnrArea',
#  'GarageCars',
#  'MoSold_2',
#  'GarageQual',
#  'MSZoning_RL',
#  'TotRmsAbvGrd',
#  'SaleType_Oth',
#  'MSZoning_RM',
#  'RoofStyle_Hip',
#  'KitchenAbvGr',
#  'WoodDeckSF',
#  'BldgType_Duplex',
#  'MasVnrType_None',
#  'MiscFeature_NA',
#  'RoofStyle_Flat',
#  'PavedDrive',
#  'Neighborhood_NridgHt',
#  'MasVnrType_Stone',
#  'Electrical_FuseP',
#  'PoolArea',
#  'Neighborhood_Edwards',
#  'Foundation_Stone',
#  'Condition1_Feedr',
#  'SaleCondition_Alloca',
#  'MSSubClass_160',
#  'GarageCond',
#  'BedroomAbvGr',
#  'Neighborhood_CollgCr',
#  'HouseStyle_1.5Unf',
#  'Foundation_Slab',
#  'SaleType_CWD',
#  'Exterior2nd_ImStucc',
#  'GarageArea',
#  'BsmtExposure',
#  'Neighborhood_IDOTRR',
#  'MiscVal',
#  'FireplaceQu',
#  'Exterior1st_WdShing',
#  'LotShape',
#  'BsmtFullBath',
#  'Neighborhood_SWISU',
#  'Foundation_PConc',
#  'GarageYrBlt',
#  'LotAreaMultSlope',
#  'Heating_GasW',
#  'GarageType_Attchd',
#  '1stFlrSF',
#  'Neighborhood_Crawfor',
#  'Foundation_CBlock',
#  'MSSubClass_45',
#  'HouseStyle_2.5Fin',
#  'LotConfig_Inside',
#  'Condition1_PosN',
#  'Condition1_Artery',
#  'SaleCondition_Normal',
#  'RoofMatl_WdShake',
#  'Neighborhood_NoRidge',
#  'Condition1_RRNn',
#  'OpenPorchSF',
#  'Exterior2nd_HdBoard',
#  'MasVnrType_BrkFace',
#  'MoSold_1',
#  'Condition1_RRNe',
#  'Neighborhood_BrkSide',
#  'GarageType_Basment',
#  'MasVnrType_BrkCmn',
#  'CentralAir',
#  'Alley_NA',
#  'LandContour_HLS',
#  'Electrical_FuseA',
#  'Neighborhood_Mitchel',
#  'LotConfig_Corner',
#  'Exterior2nd_CmentBd',
#  'BsmtFinType1',
#  'Neighborhood_OldTown',
#  'Neighborhood_MeadowV',
#  'FullBath',
#  'MSZoning_FV',
#  'SaleType_ConLI',
#  'SaleCondition_AdjLand',
#  'SaleType_New']

# %%
list(set(viejo) - set(highest))
# Out:
# ['LotArea',
#  'BsmtSFMultPoints',
#  'PoolArea',
#  'HouseStyle_2Story',
#  'SaleCondition_Partial',
#  'TSsnPorch',
#  'TotalBsmtSF_x_Bsm',
#  'OverallQual',
#  'ScreenPorch',
#  'BsmtFinSF2',
#  'GarageCond',
#  'GrLivArea',
#  'LowQualFinSF',
#  'Exterior1st_VinylSd']

# %%
def correlation_search(data, thres): ##input: dataframe de correlacion df.corr()
    #Create summary table for examining correlation between features (collinearity)
    cols = ["Feat_1", "Feat_2", "Correlation"]
    a = pd.DataFrame(columns = cols)
    co = data.columns
    for c in co:
        frame = data.loc[abs(data[c] > thres) & (data[c] < 1), [c]]
        if not frame.empty:
            f_i = frame.index
            #LLeno la tabla
            for i in f_i:
                #print(c, i, data.loc[i, c] )
                a = a.append({"Feat_1":c, "Feat_2": i, "Correlation":frame.loc[i, c]}, ignore_index = True)
    a = a.set_index(['Feat_1','Feat_2']).stack().drop_duplicates().unstack().reset_index() #evito que se repitan cruzados
    a = a.sort_values(by = "Correlation", ascending = False)
    return a

# %%
reg_col= reg_col.drop("SalePrice")

# %%
a = correlation_search(data.corr(), thres= 0)

# %%
a.loc[a["Feat_1"]== "TotalBsmtSF"]
# Out:
#            Feat_1                 Feat_2  Correlation
# 2398  TotalBsmtSF  TotalBsmtSF_x_Bsm     0.9158
# 2403  TotalBsmtSF  BsmtSFMultPoints      0.8872
# 2373  TotalBsmtSF  1stFlrSF              0.7921
# 2399  TotalBsmtSF  ConstructArea         0.7834
# 2395  TotalBsmtSF  TotalPoints           0.6048
# 2402  TotalBsmtSF  BsmtSFPoints          0.6020
# 2397  TotalBsmtSF  GarageArea_x_Car      0.5057
# 2383  TotalBsmtSF  GarageArea            0.4850
# 2382  TotalBsmtSF  GarageCars            0.4497
# 2396  TotalBsmtSF  TotalExtraPoints      0.4470
# 2377  TotalBsmtSF  KitchenQual           0.4324
# 2374  TotalBsmtSF  GrLivArea             0.4210
# 2404  TotalBsmtSF  TotBathrooms          0.4169
# 2442  TotalBsmtSF  GarageType_Attchd     0.3914
# 2425  TotalBsmtSF  HouseStyle_1Story     0.3724
# 2405  TotalBsmtSF  MSSubClass_20         0.3631
# 2381  TotalBsmtSF  GarageFinish          0.3499
# 2380  TotalBsmtSF  FireplaceQu           0.3484
# 2416  TotalBsmtSF  Neighborhood_NridgHt  0.3272
# 2379  TotalBsmtSF  Fireplaces            0.3255
# 2439  TotalBsmtSF  Foundation_PConc      0.3218
# 2375  TotalBsmtSF  BsmtFullBath          0.3126
# 2426  TotalBsmtSF  RoofStyle_Hip         0.3005
# 2401  TotalBsmtSF  LotAreaMultSlope      0.2950
# 2438  TotalBsmtSF  MasVnrType_Stone      0.2733
# 2378  TotalBsmtSF  TotRmsAbvGrd          0.2721
# 2371  TotalBsmtSF  HeatingQC             0.2659
# 2406  TotalBsmtSF  MSZoning_RL           0.2607
# 2386  TotalBsmtSF  PavedDrive            0.2464
# 2451  TotalBsmtSF  SaleCondition_Partial 0.2460
# 2450  TotalBsmtSF  SaleType_New          0.2454
# 2387  TotalBsmtSF  WoodDeckSF            0.2324
# 2388  TotalBsmtSF  OpenPorchSF           0.2316
# 2372  TotalBsmtSF  CentralAir            0.2229
# 2437  TotalBsmtSF  MasVnrType_BrkFace    0.2191
# 2432  TotalBsmtSF  Exterior1st_VinylSd   0.1900
# 2384  TotalBsmtSF  GarageQual            0.1885
# 2436  TotalBsmtSF  Exterior2nd_VinylSd   0.1830
# 2441  TotalBsmtSF  Electrical_SBrkr      0.1789
# 2385  TotalBsmtSF  GarageCond            0.1720
# 2459  TotalBsmtSF  MSSubClass_120        0.1623
# 2455  TotalBsmtSF  Neighborhood_StoneBr  0.1601
# 2415  TotalBsmtSF  Neighborhood_NoRidge  0.1428
# 2407  TotalBsmtSF  Alley_NA              0.1293
# 2400  TotalBsmtSF  TotalPorch            0.1193
# 2417  TotalBsmtSF  Neighborhood_Timber   0.1146
# 2471  TotalBsmtSF  Exterior2nd_CmentBd   0.1058
# 2452  TotalBsmtSF  New                   0.1054
# 2465  TotalBsmtSF  Exterior1st_CemntBd   0.1054
# 2408  TotalBsmtSF  LandContour_HLS       0.0925
# 2393  TotalBsmtSF  MiscVal               0.0879
# 2420  TotalBsmtSF  Condition1_PosN       0.0829
# 2412  TotalBsmtSF  Neighborhood_CollgCr  0.0822
# 2418  TotalBsmtSF  Neighborhood_Veenker  0.0820
# 2462  TotalBsmtSF  Neighborhood_Somerst  0.0806
# 2440  TotalBsmtSF  Heating_GasA          0.0804
# 2390  TotalBsmtSF  ScreenPorch           0.0795
# 2433  TotalBsmtSF  Exterior2nd_BrkFace   0.0783
# 2454  TotalBsmtSF  LotConfig_CulDSac     0.0781
# 2458  TotalBsmtSF  Functional            0.0778
# 2423  TotalBsmtSF  Condition2_PosN       0.0776
# 2429  TotalBsmtSF  RoofMatl_WdShngl      0.0709
# 2422  TotalBsmtSF  Condition2_PosA       0.0702
# 2463  TotalBsmtSF  Condition1_Norm       0.0681
# 2414  TotalBsmtSF  Neighborhood_NWAmes   0.0651
# 2461  TotalBsmtSF  Neighborhood_Blmngtn  0.0598
# 2464  TotalBsmtSF  BldgType_TwnhsE       0.0598
# 2430  TotalBsmtSF  Exterior1st_BrkFace   0.0559
# 2376  TotalBsmtSF  BedroomAbvGr          0.0526
# 2434  TotalBsmtSF  Exterior2nd_ImStucc   0.0522
# 2466  TotalBsmtSF  MiscFeature_NA        0.0519
# 2424  TotalBsmtSF  BldgType_1Fam         0.0507
# 2411  TotalBsmtSF  Neighborhood_ClearCr  0.0439
# 2431  TotalBsmtSF  Exterior1st_Plywood   0.0431
# 2448  TotalBsmtSF  MoSold_11             0.0416
# 2445  TotalBsmtSF  MoSold_1              0.0389
# 2389  TotalBsmtSF  3SsnPorch             0.0377
# 2409  TotalBsmtSF  LandContour_Low       0.0372
# 2419  TotalBsmtSF  Condition1_PosA       0.0371
# 2447  TotalBsmtSF  MoSold_9              0.0283
# 2444  TotalBsmtSF  MiscFeature_Pool      0.0274
# 2391  TotalBsmtSF  PoolArea              0.0211
# 2435  TotalBsmtSF  Exterior2nd_Plywood   0.0197
# 2468  TotalBsmtSF  MoSold_10             0.0159
# 2427  TotalBsmtSF  RoofMatl_Tar&Grv      0.0146
# 2449  TotalBsmtSF  SaleType_ConLI        0.0145
# 2413  TotalBsmtSF  Neighborhood_Mitchel  0.0142
# 2467  TotalBsmtSF  MoSold_8              0.0142
# 2394  TotalBsmtSF  YrSold                0.0128
# 2428  TotalBsmtSF  RoofMatl_WdShake      0.0128
# 2460  TotalBsmtSF  MSZoning_FV           0.0113
# 2446  TotalBsmtSF  MoSold_3              0.0104
# 2457  TotalBsmtSF  SaleType_Con          0.0096
# 2453  TotalBsmtSF  BsmtHalfBath          0.0080
# 2421  TotalBsmtSF  Condition1_RRNn       0.0077
# 2443  TotalBsmtSF  MiscFeature_Gar2      0.0055
# 2456  TotalBsmtSF  MoSold_12             0.0038
# 2410  TotalBsmtSF  LotConfig_Corner      0.0035
# 2392  TotalBsmtSF  PoolQC                0.0009
# 2469  TotalBsmtSF  SaleType_CWD          0.0004
# 2470  TotalBsmtSF  FullBath              0.0000

# %%
a.loc[(a["Feat_1"] == "ConstructArea") | (a["Feat_2"] == "ConstructArea")] ## analisis de correlac con primer best
# Out:
#        Feat_1         Feat_2  Correlation
# 10  GrLivArea  ConstructArea 0.8367

# %%
a.loc[(a["Feat_1"] == "TotalPoints") | (a["Feat_2"] == "TotalPoints")]
# Out:
#         Feat_1       Feat_2  Correlation
# 1  OverallQual  TotalPoints 0.9715

# %%
a
# Out:
#                  Feat_1                 Feat_2  Correlation
# 2   YearRemodAdd         Age                   0.9980
# 32  SaleType_New         SaleCondition_Partial 0.9864
# 27  Exterior1st_CemntBd  Exterior2nd_CmentBd   0.9830
# 30  Exterior1st_VinylSd  Exterior2nd_VinylSd   0.9781
# 24  MSSubClass_190       BldgType_2fmCon       0.9739
# 1   OverallQual          TotalPoints           0.9715
# 29  Exterior1st_MetalSd  Exterior2nd_MetalSd   0.9695
# 23  MSSubClass_80        HouseStyle_SLvl       0.9584
# 16  GarageQual           GarageCond            0.9458
# 19  GarageNewest         GarageType_NA         0.9431
# 17  PoolArea             MiscFeature_Pool      0.9405
# 22  MSSubClass_50        HouseStyle_1.5Fin     0.9357
# 15  GarageArea           GarageArea_x_Car      0.9338
# 3   BsmtQual             BsmtSFPoints          0.9253
# 0   LotArea              LotAreaMultSlope      0.9215
# 5   TotalBsmtSF          TotalBsmtSF_x_Bsm     0.9158
# 14  GarageCars           GarageArea_x_Car      0.9076
# 13  GarageCars           GarageArea            0.8924
# 28  Exterior1st_HdBoard  Exterior2nd_HdBoard   0.8892
# 6   TotalBsmtSF          BsmtSFMultPoints      0.8872
# 7   1stFlrSF             TotalBsmtSF_x_Bsm     0.8750
# 25  MSZoning_FV          Neighborhood_Somerst  0.8671
# 18  TotalBsmtSF_x_Bsm    BsmtSFMultPoints      0.8658
# 21  MSSubClass_45        HouseStyle_1.5Unf     0.8643
# 31  Exterior1st_Wd Sdng  Exterior2nd_Wd Sdng   0.8628
# 11  Fireplaces           FireplaceQu           0.8625
# 12  FireplaceQu          TotalExtraPoints      0.8572
# 26  Exterior1st_AsbShng  Exterior2nd_AsbShng   0.8539
# 10  GrLivArea            ConstructArea         0.8367
# 8   2ndFlrSF             HouseStyle_2Story     0.8122
# 9   GrLivArea            TotRmsAbvGrd          0.8089
# 20  BsmtSFPoints         BsmtSFMultPoints      0.8066
# 4   BsmtFinType2         BsmtFinSF2            0.8031

# %%
# #first import the module
import lr_module_mae
#importing the class Linear_Regression
from lr_module_mae import Linear_Regression 
#Rescaling and transforming
scale = RobustScaler()
r_c = reg_col.drop("SalePrice")
t = all_data[r_c]
t = t.iloc[:len(y_train), :]
t[r_c] = scale.fit_transform(t[r_c])
t["SalePrice"] = np.log1p(y_train)
reg_mae = Linear_Regression(dataset = t, n_iter= 100000, alpha =0.1)
print(reg_mae.regressor(summary = True))
# Out:
# Cost iteration number 0 : 72.51089
# Summary:
# Coefficients: [[ 1.19679182e+01]
#  [ 1.44194906e-01]
#  [ 1.72500277e-01]
#  [ 1.46403830e-03]
#  [ 9.38038884e-02]
#  [ 7.71568350e-02]
#  [ 2.60484128e-02]
#  [ 1.67735553e-02]
#  [ 6.90045760e-02]
#  [-6.39708406e-02]
#  [ 1.58942601e-02]]
# Root Mean Square Error: 0.1877
# My R2 for Training Set: 0.8683
# My R2 for Test Set: 0.8124
# None

# %%
all_data.shape, y_train.shape
# Out:
# ((2905, 245), (1460, 1))

# %%
viejo = ['FireplaceQu', 'BsmtSFPoints', 'TotalBsmtSF', 'GarageArea', 'GarageCars', 'OverallQual', 'GrLivArea', 
               'TotalBsmtSF_x_Bsm', '1stFlrSF', 'PoolArea', 'LotArea', 'SaleCondition_Partial', 'Exterior1st_VinylSd',
               'GarageCond', 'HouseStyle_2Story', 'BsmtSFMultPoints', 'ScreenPorch', 'LowQualFinSF', 'BsmtFinSF2',
               'TSsnPorch']
len(viejo)
# Out:
# 20

# %%
a
# Out:
#                  Feat_1                 Feat_2  Correlation
# 2   YearRemodAdd         Age                   0.9980
# 32  SaleType_New         SaleCondition_Partial 0.9864
# 27  Exterior1st_CemntBd  Exterior2nd_CmentBd   0.9830
# 30  Exterior1st_VinylSd  Exterior2nd_VinylSd   0.9781
# 24  MSSubClass_190       BldgType_2fmCon       0.9739
# 1   OverallQual          TotalPoints           0.9715
# 29  Exterior1st_MetalSd  Exterior2nd_MetalSd   0.9695
# 23  MSSubClass_80        HouseStyle_SLvl       0.9584
# 16  GarageQual           GarageCond            0.9458
# 19  GarageNewest         GarageType_NA         0.9431
# 17  PoolArea             MiscFeature_Pool      0.9405
# 22  MSSubClass_50        HouseStyle_1.5Fin     0.9357
# 15  GarageArea           GarageArea_x_Car      0.9338
# 3   BsmtQual             BsmtSFPoints          0.9253
# 0   LotArea              LotAreaMultSlope      0.9215
# 5   TotalBsmtSF          TotalBsmtSF_x_Bsm     0.9158
# 14  GarageCars           GarageArea_x_Car      0.9076
# 13  GarageCars           GarageArea            0.8924
# 28  Exterior1st_HdBoard  Exterior2nd_HdBoard   0.8892
# 6   TotalBsmtSF          BsmtSFMultPoints      0.8872
# 7   1stFlrSF             TotalBsmtSF_x_Bsm     0.8750
# 25  MSZoning_FV          Neighborhood_Somerst  0.8671
# 18  TotalBsmtSF_x_Bsm    BsmtSFMultPoints      0.8658
# 21  MSSubClass_45        HouseStyle_1.5Unf     0.8643
# 31  Exterior1st_Wd Sdng  Exterior2nd_Wd Sdng   0.8628
# 11  Fireplaces           FireplaceQu           0.8625
# 12  FireplaceQu          TotalExtraPoints      0.8572
# 26  Exterior1st_AsbShng  Exterior2nd_AsbShng   0.8539
# 10  GrLivArea            ConstructArea         0.8367
# 8   2ndFlrSF             HouseStyle_2Story     0.8122
# 9   GrLivArea            TotRmsAbvGrd          0.8089
# 20  BsmtSFPoints         BsmtSFMultPoints      0.8066
# 4   BsmtFinType2         BsmtFinSF2            0.8031

# %%
a["Feat_1"].value_counts().index
# Out:
# Index(['GarageCars', 'TotalBsmtSF', 'GrLivArea', 'SaleType_New',
#        'MSSubClass_190', 'Exterior1st_CemntBd', 'LotArea',
#        'Exterior1st_MetalSd', 'YearRemodAdd', 'Exterior1st_Wd Sdng',
#        'OverallQual', 'BsmtSFPoints', 'GarageNewest', 'MSSubClass_80',
#        'Exterior1st_AsbShng', '2ndFlrSF', '1stFlrSF', 'FireplaceQu',
#        'GarageQual', 'PoolArea', 'MSSubClass_45', 'TotalBsmtSF_x_Bsm',
#        'BsmtQual', 'BsmtFinType2', 'MSSubClass_50', 'MSZoning_FV',
#        'Fireplaces', 'Exterior1st_HdBoard', 'Exterior1st_VinylSd',
#        'GarageArea'],
#       dtype='object')

# %%
viejo
# Out:
# ['FireplaceQu',
#  'BsmtSFPoints',
#  'TotalBsmtSF',
#  'GarageArea',
#  'GarageCars',
#  'OverallQual',
#  'GrLivArea',
#  'TotalBsmtSF_x_Bsm',
#  '1stFlrSF',
#  'PoolArea',
#  'LotArea',
#  'SaleCondition_Partial',
#  'Exterior1st_VinylSd',
#  'GarageCond',
#  'HouseStyle_2Story',
#  'BsmtSFMultPoints',
#  'ScreenPorch',
#  'LowQualFinSF',
#  'BsmtFinSF2',
#  'TSsnPorch']

# %%
a[a["Feat_1"] == "BsmtSFPoints"]
# Out:
#           Feat_1            Feat_2  Correlation
# 20  BsmtSFPoints  BsmtSFMultPoints 0.8066

# %%
a.loc[a["Feat_1"] == ['FireplaceQu',
 'BsmtSFPoints',
 'TotalBsmtSF',
 'GarageArea',
 'GarageCars',
 'OverallQual',
 'GrLivArea',
 'TotalBsmtSF_x_Bsm',
 '1stFlrSF',
 'PoolArea',
 'LotArea',
 'SaleCondition_Partial',
 'Exterior1st_VinylSd',
 'GarageCond',
 'HouseStyle_2Story',
 'BsmtSFMultPoints',
 'ScreenPorch',
 'LowQualFinSF',
 'BsmtFinSF2',
 'TSsnPorch'], :]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-9c3236a3cc27> in <module>
#      18  'LowQualFinSF',
#      19  'BsmtFinSF2',
# ---> 20  'TSsnPorch'], :]
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      62         other = item_from_zerodim(other)
#      63
# ---> 64         return method(self, other)
#      65
#      66     return new_method
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops\__init__.py in wrapper(self, other)
#     524         rvalues = extract_array(other, extract_numpy=True)
#     525
# --> 526         res_values = comparison_op(lvalues, rvalues, op)
#     527
#     528         return _construct_result(self, res_values, index=self.index, name=res_name)
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in comparison_op(left, right, op)
#     232         #  The ambiguous case is object-dtype.  See GH#27803
#     233         if len(lvalues) != len(rvalues):
# --> 234             raise ValueError("Lengths must match to compare")
#     235
#     236     if should_extension_dispatch(lvalues, rvalues):
#
# ValueError: Lengths must match to compare

# %%
corr = data[data.SalePrice>1].corr()
top_corr_cols = corr[abs((corr.SalePrice)>=.26)].SalePrice.sort_values(ascending=False).keys()
top_corr = corr.loc[top_corr_cols, top_corr_cols]
dropSelf = np.zeros_like(top_corr)
dropSelf[np.triu_indices_from(dropSelf)] = True
plt.figure(figsize=(20, 20))
sns.heatmap(top_corr, cmap=sns.diverging_palette(220, 10, as_cmap=True), annot=True, fmt=".2f", mask=dropSelf)
sns.set(font_scale=0.5)
plt.show()
del corr, dropSelf, top_corr

# %%
viejo
# Out:
# ['FireplaceQu',
#  'BsmtSFPoints',
#  'TotalBsmtSF',
#  'GarageArea',
#  'GarageCars',
#  'OverallQual',
#  'GrLivArea',
#  'TotalBsmtSF_x_Bsm',
#  '1stFlrSF',
#  'PoolArea',
#  'LotArea',
#  'SaleCondition_Partial',
#  'Exterior1st_VinylSd',
#  'GarageCond',
#  'HouseStyle_2Story',
#  'BsmtSFMultPoints',
#  'ScreenPorch',
#  'LowQualFinSF',
#  'BsmtFinSF2',
#  'TSsnPorch']

# %%
####Revisar para generar viejo: chequear puntos rojos (sobre .8) y eliminar el que tenga menor
#correlacion con SalePrice
